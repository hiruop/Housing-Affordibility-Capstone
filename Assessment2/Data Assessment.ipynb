# %% [markdown]
# # Data Assessment

# %% [markdown]
# ##### Group 02

# %% [markdown]
# # Project Title : - HOUSING AFFORDABILITY IN CANADA

# %% [markdown]
# ##### The purpose of this challenge is to anticipate the future affordability of housing in Canada.

# %% [markdown]
# ### Import Require Libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

# %%
def sniff_modified(df):
    with pd.option_context("display.max_colwidth", 20):
        info = pd.DataFrame()
        info['data type'] = df.dtypes
        info['percent missing'] = df.isnull().sum()*100/len(df)
        info['No. unique'] = df.apply(lambda x: len(x.unique()))
        info['unique values'] = df.apply(lambda x: x.unique())
        return info.sort_values('data type')

# %% [markdown]
# ### Import Dataset

# %%
canada = pd.read_csv('C:/Users/Hiren/Desktop/ST.Clair/sem 4/402-Capstone/housing-affordability-in-canada/housing-supply-price-rental.csv')

# %%
canada.head(5)
# Out:
#    Unnamed: 0    year  total_dwelling  single_detached  multiple  \
# 0         0.0  1990.0          3297.0           2847.0     450.0
# 1         1.0  1991.0          1950.0           1589.0     361.0
# 2         2.0  1992.0          2310.0           1683.0     627.0
# 3         3.0  1993.0          2425.0           1874.0     551.0
# 4         4.0  1994.0          3197.0           2441.0     756.0
#
#    semi_detached    row  apartment  total_dwelling_market  \
# 0           57.0    6.0      387.0                 2274.0
# 1           14.0    0.0      347.0                 1438.0
# 2           64.0   10.0      553.0                 1821.0
# 3           52.0   83.0      416.0                 1702.0
# 4           72.0  410.0      274.0                 1664.0
#
#    homeownership_freehold  ...  one_bedroom  two_bedroom  three_bedroom  \
# 0                  2004.0  ...          418          524            608
# 1                  1085.0  ...          424          531            630
# ...

# %% [markdown]
# ### Assessment for Data Quality
# #### Identifying problems in each column

# %%
sniff_modified(canada)
# Out:
#                                   data type  percent missing  No. unique  \
# one_bedroom                           int64         0.000000         565
# three_bedroom                         int64         0.000000         665
# two_bedroom                           int64         0.000000         622
# vacancy_rate_seniors                float64        15.714286         127
# vacancy_rate_condo                  float64        51.785714         282
# HPI_change                          float64        35.982143         670
# CPI_change                          float64        43.214286         547
# owned_accommodation_costs_change    float64        49.375000         568
# rental_accommodation_costs_change   float64        49.375000         567
# Unnamed: 0                          float64         0.446429          33
# rental_avilability_rate             float64        15.714286          94
# population                          float64        15.714286         877
# ...

# %%
canada.describe()
# Out:
#         Unnamed: 0         year  total_dwelling  single_detached  \
# count  1115.000000  1120.000000      944.000000       944.000000
# mean     15.439462  2005.500982     7744.455508      3795.960805
# std       9.212954     9.235839    14087.306244      6966.388674
# min       0.000000  1990.000000      151.000000       117.000000
# 25%       7.000000  1997.750000      769.250000       430.750000
# 50%      15.000000  2005.500000     2256.000000      1192.000000
# 75%      23.000000  2013.250000     5878.250000      3133.750000
# max      31.000000  2021.000000    85180.000000     51114.000000
#
#            multiple  semi_detached           row     apartment  \
# count    944.000000     944.000000    944.000000    944.000000
# mean    3953.541314     529.031780    836.416314   2588.093220
# std     7670.701390    1039.896008   1877.404065   5336.020987
# min        0.000000       0.000000      0.000000      0.000000
# ...

# %% [markdown]
# ##### The above output shows disposable_income_change, owned_accommodation_costs_change, CPI_change, HPI_change, vacancy_rate_condo, rental_accommodation_costs_change columns have missing values. (Similarly, Unnamed has missing values and significant unique values; therefore, we will remove it because it is redundant.)

# %% [markdown]
# # Assessment for Data Fitness

# %%
canada['region'].unique()
# Out:
# array(['Brandon', 'vancouver', 'winnipeg', 'calgary', 'prince_edward',
#        'ottawa', 'oshawa', 'saguenay', 'hamilton', 'abbotsford',
#        'windsor', 'gatineau', 'frederictoin', 'sudbury', 'peterborough',
#        'ragina', 'brantford', 'kentville', 'quebec', 'moncton', 'toronto',
#        'thunder_bay', 'guelph', 'saint_john', 'quebec_cma', 'sherbrooke',
#        'saskatoon', 'montreal', 'barrie', 'victoria', 'ottawa_gatineau',
#        'edmonton', 'halifax', 'kingston'], dtype=object)

# %% [markdown]
# #### Regions of Canada which are included in this project dataset.

# %%
#review the data types of each column
canada.dtypes
# Out:
# Unnamed: 0                           float64
# year                                 float64
# total_dwelling                       float64
# single_detached                      float64
# multiple                             float64
# semi_detached                        float64
# row                                  float64
# apartment                            float64
# total_dwelling_market                float64
# homeownership_freehold               float64
# rental                               float64
# homeownership_condo                  float64
# other                                float64
# completed                            float64
# res_building_permit                  float64
# res_building_permit_amount           float64
# completed_but_unabsorbed_homes       float64
# new_single_and_semi_detached         float64
# new_rows_and_apartment               float64
# rental_vacancy_rate                  float64
# rental_avilability_rate              float64
# ...

# %%
#Confirm the rename columns
canada.head()
# Out:
#    Unnamed: 0    year  total_dwelling  single_detached  multiple  \
# 0         0.0  1990.0          3297.0           2847.0     450.0
# 1         1.0  1991.0          1950.0           1589.0     361.0
# 2         2.0  1992.0          2310.0           1683.0     627.0
# 3         3.0  1993.0          2425.0           1874.0     551.0
# 4         4.0  1994.0          3197.0           2441.0     756.0
#
#    semi_detached    row  apartment  total_dwelling_market  \
# 0           57.0    6.0      387.0                 2274.0
# 1           14.0    0.0      347.0                 1438.0
# 2           64.0   10.0      553.0                 1821.0
# 3           52.0   83.0      416.0                 1702.0
# 4           72.0  410.0      274.0                 1664.0
#
#    homeownership_freehold  ...  one_bedroom  two_bedroom  three_bedroom  \
# 0                  2004.0  ...          418          524            608
# 1                  1085.0  ...          424          531            630
# ...

# %%
#determining the shape of the column
canada.shape
# Out:
# (1120, 38)

# %% [markdown]
# ### Cleaning Data and removing null values

# %%
#checking the null values
canada.isnull().values.any()
# Out:
# True

# %%
canada.fillna( method ='ffill', inplace = True)

# %%
canada.isnull()
# Out:
#       Unnamed: 0   year  total_dwelling  single_detached  multiple  \
# 0          False  False           False            False     False
# 1          False  False           False            False     False
# 2          False  False           False            False     False
# 3          False  False           False            False     False
# 4          False  False           False            False     False
# ...          ...    ...             ...              ...       ...
# 1115       False  False           False            False     False
# 1116       False  False           False            False     False
# 1117       False  False           False            False     False
# 1118       False  False           False            False     False
# 1119       False  False           False            False     False
#
#       semi_detached    row  apartment  total_dwelling_market  \
# 0             False  False      False                  False
# ...

# %%
canada_clean = canada.dropna(how='all', axis=1)
canada_clean.head()
# Out:
#    Unnamed: 0    year  total_dwelling  single_detached  multiple  \
# 0         0.0  1990.0          3297.0           2847.0     450.0
# 1         1.0  1991.0          1950.0           1589.0     361.0
# 2         2.0  1992.0          2310.0           1683.0     627.0
# 3         3.0  1993.0          2425.0           1874.0     551.0
# 4         4.0  1994.0          3197.0           2441.0     756.0
#
#    semi_detached    row  apartment  total_dwelling_market  \
# 0           57.0    6.0      387.0                 2274.0
# 1           14.0    0.0      347.0                 1438.0
# 2           64.0   10.0      553.0                 1821.0
# 3           52.0   83.0      416.0                 1702.0
# 4           72.0  410.0      274.0                 1664.0
#
#    homeownership_freehold  ...  one_bedroom  two_bedroom  three_bedroom  \
# 0                  2004.0  ...          418          524            608
# 1                  1085.0  ...          424          531            630
# ...

# %%
canada_clean.isnull()
# Out:
#       Unnamed: 0   year  total_dwelling  single_detached  multiple  \
# 0          False  False           False            False     False
# 1          False  False           False            False     False
# 2          False  False           False            False     False
# 3          False  False           False            False     False
# 4          False  False           False            False     False
# ...          ...    ...             ...              ...       ...
# 1115       False  False           False            False     False
# 1116       False  False           False            False     False
# 1117       False  False           False            False     False
# 1118       False  False           False            False     False
# 1119       False  False           False            False     False
#
#       semi_detached    row  apartment  total_dwelling_market  \
# 0             False  False      False                  False
# ...

# %% [markdown]
# #### -> The result above demonstrates that there are no missing values for any of the records.
# #### -> We have the information about the house sold data of the Canada's Toronto region like rent, house type, total dwelling, market values
# #### -> we are attempting to highlight many reasons why individuals are unable to rent or buy a home, thus we will utilize visualization techniques to identify certain places in Canada where it is difficult to afford a home.

# %%
canada_clean.tail()
# Out:
#       Unnamed: 0    year  total_dwelling  single_detached  multiple  \
# 1115        27.0  2017.0           412.0            300.0     112.0
# 1116        28.0  2018.0           412.0            300.0     112.0
# 1117        29.0  2019.0           412.0            300.0     112.0
# 1118        30.0  2020.0           412.0            300.0     112.0
# 1119        31.0  2021.0           412.0            300.0     112.0
#
#       semi_detached   row  apartment  total_dwelling_market  \
# 1115            4.0  93.0       15.0                  412.0
# 1116            4.0  93.0       15.0                  412.0
# 1117            4.0  93.0       15.0                  412.0
# 1118            4.0  93.0       15.0                  412.0
# 1119            4.0  93.0       15.0                  412.0
#
#       homeownership_freehold  ...  one_bedroom  two_bedroom  three_bedroom  \
# 1115                   397.0  ...          975         1155           1612
# ...

# %% [markdown]
# # Answering Research Questions

# %% [markdown]
# ### 1. Data Collection:

# %% [markdown]
# #### 1.Informed Consent : If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?

# %% [markdown]
# -> We have collected our dataset from various sources and all the datasets were taken from open government and Bank's sources. SO, we haven't collected any person's sensitive or personal data.

# %% [markdown]
# #### 2.Collection Bias : Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?

# %% [markdown]
# -> All the information was collected from the various official open sources of both Canadian Government and Banks . We were concerned about the possibility of biasness in the data, because it contains all the information about houses but, all the data are publicly available so it must have been mitigated.

# %% [markdown]
# #### 3.Limit PII Exposure : Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?

# %% [markdown]
# -> The datasets which we are using is publicly available and it is from official sources, so we have not collected any Personally Identifiable Information of any person.

# %% [markdown]
# #### 4.Downstream Bias Mitigation : Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?

# %% [markdown]
# -> We do not have any bias data.

# %% [markdown]
# # 2. Data Storage:

# %% [markdown]
# #### 1.Data security: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?

# %% [markdown]
# -> Although, our data is publicly available, our team will definitely treat sensitive financial data with the full confidentiality. The team members will make sure that nobody except our core team has access to the sensitive information. GitHub will also be used to store all the data, but again only the core team will have access to it.

# %% [markdown]
# #### 2.Right to be forgotten : Do we have a mechanism through which an individual can request their personal information be removed?

# %% [markdown]
# -> All the information we collected is available as open source, so there is no need of having this mechanism.

# %% [markdown]
# #### 3.Data retention plan : Is there a schedule or plan to delete the data after it is no longer needed?

# %% [markdown]
# -> The data we collected is openly available, so we do not have any plans to store the data.

# %% [markdown]
# # 3. Analysis:

# %% [markdown]
# #### 1.Missing Perspectives : Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?

# %% [markdown]
# -> This analysis is not available in our data.

# %% [markdown]
# #### 2.Dataset Bias : Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?

# %% [markdown]
# -> We have access to a very large data set, so the information which we will derive will be not bias.

# %% [markdown]
# #### 3.Honest representation : Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?

# %% [markdown]
# -> Our team has tried their best to represent data in it's true form, without any misleading content. So, all the information which we will provide using this data will be in true manner.

# %% [markdown]
# #### 4.Privacy in analysis : Have we ensured that data with PII are not used or displayed unless necessary for the analysis?

# %% [markdown]
# -> Yes, we have ensured that no sensitive data is displayed and nevertheless, our data is publicly available to access.

# %% [markdown]
# #### 5.Auditability : Is the process of generating the analysis well documented and reproducible if we discover issues in the future?

# %% [markdown]
# -> Each and every step of this project is going to be well documented and all the details of this project is going to be saved in our GitHub Repositary, so it will be easy to retract information if needed.

# %% [markdown]
# # 4. Modeling:

# %% [markdown]
# #### 1.Proxy discrimination : Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?

# %% [markdown]
# -> Yes, we ensured that the model will not rely on proxies.

# %% [markdown]
# #### 2.Fairness across groups: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?

# %% [markdown]
# -> Our models will be fair with respect to all the affected groups.

# %% [markdown]
# #### 3.Metric selection : Have we considered the effects of optimizing for our defined metrics and considered additional metrics?

# %% [markdown]
# -> We are going to considered all the metrics while making this project.

# %% [markdown]
# #### 4.Explainability : Can we explain in understandable terms a decision the model made in cases where a justification is needed?

# %% [markdown]
# -> We are going to provide clear explanation of our all the model results.

# %% [markdown]
# #### 5.Communicate bias : Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?

# %% [markdown]
# -> Our project is open source and we are going to provide all the details of our project including all the model results.

# %% [markdown]
# # 5. Deployment:

# %% [markdown]
# #### 1.Monitoring and Evaluation : How are we planning to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?

# %% [markdown]
# -> We are planning to monitor our models based on all the metric scores. We are going to check the accuracy of our models compare to our baseline models and based on that we are planning to make predictions about the affordability of houses in canada.

# %% [markdown]
# #### 2.Redress : Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?

# %% [markdown]
# -> We are planning to predict the house affordability in canada based on our models accuracy, but if there will be any harm we will try to eradicate our mistake by upgrading our models.

# %% [markdown]
# #### 3.Roll Back : Is there a way to turn off or roll back the model in production if necessary?

# %% [markdown]
# -> Yes, in case of model failure we will be able to completely retract it from the public platform.

# %% [markdown]
# #### 4.Unintended Use: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?

# %% [markdown]
# -> We have not discussed about this thing so, we are not checking this off from the list. Meanwhile, we will discuss about this issue with our team and then we will address this issue.

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Heatmap

# %%
#correlation matrix as ususal
import matplotlib.pyplot as plt
import seaborn as sns
#plt.figure(figsize=(20,20))
#sns.heatmap(canada_clean.corr(),annot=True,cmap='coolwarm')
#plt.savefig('heatmap.png')

# %% [markdown]
# ### Visualization

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode,plot, iplot

# %%
#!pip install cufflinks

# %%
import cufflinks as cf
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.17.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#trying to plot year 
sns.histplot(data=canada_clean, x="total_dwelling", log_scale=True)
# Out:
# <AxesSubplot:xlabel='total_dwelling', ylabel='Count'>

# %% [markdown]
# #### According to the total housing histogram, the most typical total dwelling cost is between 40K-60K $.

# %%
sns.relplot(data=canada_clean, x="year", y="CPI_change", kind='line')

# %% [markdown]
# #### House Housing Index in Canada averaged 70 points, reaching an all time high of 160.10 points

# %%
#toronto_clean[''].plot(kind='box')

sns.histplot(data=canada_clean, x="one_bedroom", y="year", kde=True)
# Out:
# <AxesSubplot:xlabel='one_bedroom', ylabel='year'>

# %% [markdown]
# #### Here we can clearly see that how the Rent of houses with one bedroom increased over the years.

# %%
sns.histplot(data=canada_clean, x="two_bedroom", y="year", kde=True)
# Out:
# <AxesSubplot:xlabel='two_bedroom', ylabel='year'>

# %% [markdown]
# #### Here we can clearly see that how the Mortgage of houses with Two bedroom increased over the years.

# %%
#toronto_clean['three_bedroom'].plot(kind='box')
sns.histplot(data=canada_clean,y="year", x="three_bedroom", kde=True)
# Out:
# <AxesSubplot:xlabel='three_bedroom', ylabel='year'>

# %% [markdown]
# #### we can understand that how the Mortgage for 3BHK houses over many decades crossed the mark of 2000+ dollars in Canada and how its affected the house renter's pocket to compromise with the little homes.

# %%
#correlation of a column
def corr_of_a_column(df,column_name,how_many=None,ax=None):
    how_many = len(df)if how_many == None else how_many
    cor = df.corr()[[column_name]].sort_values(by=column_name,ascending=False)[:how_many]
    print(cor)
    sns.heatmap(cor,annot=True,cmap=sns.cubehelix_palette(start=.5,rot=-.5,as_cmap=True),ax=ax)

# %% [markdown]
# #### HPI is highly correlated to the new total dwellings?

# %%
corr_of_a_column(canada_clean, 'HPI_change')
# Out:
#                                    HPI_change
# HPI_change                           1.000000
# owned_accommodation_costs_change     0.396691
# CPI_change                           0.294636
# labour_participation_rate            0.165952
# employment_change                    0.119138
# disposable_income_change             0.118406
# rental_accommodation_costs_change    0.113854
# vacancy_rate_condo                   0.099622
# two_bedroom                          0.070375
# one_bedroom                          0.069587
# three_bedroom                        0.064051
# vacancy_rate_seniors                 0.054067
# single_detached                      0.045066
# homeownership_condo                  0.043389
# bachelor                             0.033626
# homeownership_freehold               0.033488
# total_dwelling_market                0.028743
# total_dwelling                       0.028477
# res_building_permit                  0.018409
# ...

# %% [markdown]
# #### HPL is correlated to total dwelling but owned_accomodation_costs_change is highly correlated to HPL.

# %%
#toronto_clean['owned_accommodation_costs_change'].plot(kind='hist')
sns.histplot(data=canada_clean, x="owned_accommodation_costs_change")
# Out:
# <AxesSubplot:xlabel='owned_accommodation_costs_change', ylabel='Count'>

# %% [markdown]
# #### Most owned accomodation cost will change from -5 to 5 range.

# %%
canada_clean.columns
# Out:
# Index(['Unnamed: 0', 'year', 'total_dwelling', 'single_detached', 'multiple',
#        'semi_detached', 'row', 'apartment', 'total_dwelling_market',
#        'homeownership_freehold', 'rental', 'homeownership_condo', 'other',
#        'completed', 'res_building_permit', 'res_building_permit_amount',
#        'completed_but_unabsorbed_homes', 'new_single_and_semi_detached',
#        'new_rows_and_apartment', 'rental_vacancy_rate',
#        'rental_avilability_rate', 'vacancy_rate_seniors', 'vacancy_rate_condo',
#        'HPI_change', 'CPI_change', 'owned_accommodation_costs_change',
#        'rental_accommodation_costs_change', 'bachelor', 'one_bedroom',
#        'two_bedroom', 'three_bedroom', 'population',
#        'labour_participation_rate', 'employment_change', 'unemployment_rate',
#        'disposable_income_change', 'migration', 'region'],
#       dtype='object')

# %%
canada_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1120 entries, 0 to 1119
# Data columns (total 38 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed: 0                         1120 non-null   float64
#  1   year                               1120 non-null   float64
#  2   total_dwelling                     1120 non-null   float64
#  3   single_detached                    1120 non-null   float64
#  4   multiple                           1120 non-null   float64
#  5   semi_detached                      1120 non-null   float64
#  6   row                                1120 non-null   float64
#  7   apartment                          1120 non-null   float64
#  8   total_dwelling_market              1120 non-null   float64
#  9   homeownership_freehold             1120 non-null   float64
#  10  rental                             1120 non-null   float64
# ...

# %%
def get_continuous_df(df):
    return df.select_dtypes(include=[np.int64, np.float64])

# Get df with columns having categorical variables
def get_categorical_df(df):
    return df.select_dtypes(include=['object'])

# %%
continuous_df = get_continuous_df(canada_clean)
continuous_df.head()
# Out:
#    Unnamed: 0    year  total_dwelling  single_detached  multiple  \
# 0         0.0  1990.0          3297.0           2847.0     450.0
# 1         1.0  1991.0          1950.0           1589.0     361.0
# 2         2.0  1992.0          2310.0           1683.0     627.0
# 3         3.0  1993.0          2425.0           1874.0     551.0
# 4         4.0  1994.0          3197.0           2441.0     756.0
#
#    semi_detached    row  apartment  total_dwelling_market  \
# 0           57.0    6.0      387.0                 2274.0
# 1           14.0    0.0      347.0                 1438.0
# 2           64.0   10.0      553.0                 1821.0
# 3           52.0   83.0      416.0                 1702.0
# 4           72.0  410.0      274.0                 1664.0
#
#    homeownership_freehold  ...  bachelor  one_bedroom  two_bedroom  \
# 0                  2004.0  ...     310.0          418          524
# 1                  1085.0  ...     318.0          424          531
# ...

# %%
categorical_df = get_categorical_df(canada_clean)
categorical_df.head()
# Out:
#     region
# 0  Brandon
# 1  Brandon
# 2  Brandon
# 3  Brandon
# 4  Brandon

# %%
#def plot_base_relation(df, figsize=(20, 200)):
    columns = df.columns.tolist()
    _, axs = plt.subplots(len(columns), 4, figsize=figsize)
    
    for idx, column in enumerate(columns):
        # To get distribution of data
        sns.histplot(
            x=df[column],
            kde=False,
            color='#65b87b', alpha=.7,
            ax=axs[idx][0]
        )

        # To get knowledge about outliers
        sns.boxplot(
            x=df[column],
            color='#6fb9bd',
            ax=axs[idx][1]
        )

        # To get its realtion with SalePrice
        sns.scatterplot(
            x=column, y='HPI_change', data=df,
            color='#706dbd', alpha=.7, s=80,
            ax=axs[idx][2]
        )
        
        # To get count plot for `column`
        sns.countplot(
            x=column, data=df,
            color='#42b0f5', alpha=.7,
            ax=axs[idx][3]
        )

plot_base_relation(continuous_df)
# Out:
#   File "C:\Users\Hiren\AppData\Local\Temp/ipykernel_14456/152956965.py", line 2
#     columns = df.columns.tolist()
#     ^
# IndentationError: unexpected indent

# %%
sns.relplot(data=canada_clean, x="year", y="HPI_change", kind="line")

# %% [markdown]
# #### It is apparent that the change in the HPI is lower in 2009. Furthermore, 2009 was a year of severe recession, thus we may deduce that the change in the HPI in Toronto is low as a result of the recession in 2009.

# %%
from scipy.stats import zscore, pearsonr

# %%
def get_corr(data_1, data_2):
    return round(pearsonr(data_1, data_2)[0], 2)
    
    
def get_corr_info_for_df(df):
    columns = df.columns.tolist()
    displayed = []
    def is_displayed(main_column, secondary_column, displayed_list):
        return any([
            True for tup in displayed_list if 
            (tup[0] == main_column and tup[1] == secondary_column) 
            or 
            (tup[1] == main_column and tup[0] == secondary_column)
        ])

    
    # main column is the one for which we'll find all the corr info
    # related to secondary column
    for main_column in columns:
        for secondary_column in columns:
            if secondary_column != main_column and not is_displayed(main_column, secondary_column, displayed):
                corr = get_corr(df[main_column], df[secondary_column])
                if corr >= .7 or corr <= -.7:
                    # print only if pearson correlation is high (.7 to .9) or very high (.9 to 1)
                    print(f'{secondary_column} - {main_column}: {corr}')
                    displayed.append((main_column, secondary_column))
                    
                    
get_corr_info_for_df(continuous_df)
# Out:
# year - Unnamed: 0: 1.0
# bachelor - Unnamed: 0: 0.75
# one_bedroom - Unnamed: 0: 0.76
# two_bedroom - Unnamed: 0: 0.76
# three_bedroom - Unnamed: 0: 0.74
# bachelor - year: 0.75
# one_bedroom - year: 0.76
# two_bedroom - year: 0.76
# three_bedroom - year: 0.74
# single_detached - total_dwelling: 0.95
# multiple - total_dwelling: 0.97
# semi_detached - total_dwelling: 0.88
# row - total_dwelling: 0.9
# apartment - total_dwelling: 0.9
# total_dwelling_market - total_dwelling: 1.0
# homeownership_freehold - total_dwelling: 0.96
# rental - total_dwelling: 0.72
# homeownership_condo - total_dwelling: 0.89
# completed - total_dwelling: 0.99
# res_building_permit - total_dwelling: 1.0
# res_building_permit_amount - total_dwelling: 0.93
# completed_but_unabsorbed_homes - total_dwelling: 0.79
# new_single_and_semi_detached - total_dwelling: 0.78
# new_rows_and_apartment - total_dwelling: 0.72
# population - total_dwelling: 0.96
# migration - total_dwelling: 0.88
# ...

# %% [markdown]
# #### Multiple, row, apartment, and condo are all closely connected with total residence. As a result, the majority of houses in Toronto are multi-family, row, apartment, or condo.
# #### We may deduce from the connection that the majority of people live in two-bedroom and three-bedroom homes since population is substantially associated to two-bedroom and three-bedroom homes.

# %% [markdown]
# #### We can find the following websites for reference:
# • Canada Mortgage and Housing Corporation (CMHC): https://www.cmhc-schl.gc.ca/en/
#  • Statistics Canada: https://www.statcan.gc.ca/eng/start
#  • Royal Bank of Canada (RBC): https://www.rbc.com/economics/economic-reports/housing-trends-and-affordability.html
#  • Canadian Real Estate Association (CREA): https://www.crea.ca/

# %%
mrrate = pd.read_csv('C:/Users/Hiren/Desktop/ST.Clair/sem 4/402-Capstone/housing-affordability-in-canada/Mortage and Interest rates csv/Mortgage and interest rate.csv')

# %%
mrrate.dtypes
# Out:
# Date              object
# Mortgage Rate    float64
# Interest Rate    float64
# dtype: object

# %%
data = pd.concat([canada_clean, mrrate], axis=1)

# %%
data.head(70)
# Out:
#     Unnamed: 0    year  total_dwelling  single_detached  multiple  \
# 0          0.0  1990.0          3297.0           2847.0     450.0
# 1          1.0  1991.0          1950.0           1589.0     361.0
# 2          2.0  1992.0          2310.0           1683.0     627.0
# 3          3.0  1993.0          2425.0           1874.0     551.0
# 4          4.0  1994.0          3197.0           2441.0     756.0
# ..         ...     ...             ...              ...       ...
# 65         1.0  1991.0          1349.0           1006.0     343.0
# 66         2.0  1992.0          1620.0           1261.0     359.0
# 67         3.0  1993.0          1540.0           1210.0     330.0
# 68         4.0  1994.0          1529.0           1201.0     328.0
# 69         5.0  1995.0          1104.0            840.0     264.0
#
#     semi_detached    row  apartment  total_dwelling_market  \
# 0            57.0    6.0      387.0                 2274.0
# ...

# %%
#data.to_csv('C:/Users/Hiren/Desktop/ST.Clair/sem 4/402-Capstone/housing-affordability-in-canada/Mortage and Interest rates csv/data.csv', index=False)

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
data['region_encoded'] = label_encoder.fit_transform(data['region'])
print(data)
# Out:
#       Unnamed: 0    year  total_dwelling  single_detached  multiple  \
# 0            0.0  1990.0          3297.0           2847.0     450.0
# 1            1.0  1991.0          1950.0           1589.0     361.0
# 2            2.0  1992.0          2310.0           1683.0     627.0
# 3            3.0  1993.0          2425.0           1874.0     551.0
# 4            4.0  1994.0          3197.0           2441.0     756.0
# ...          ...     ...             ...              ...       ...
# 1115        27.0  2017.0           412.0            300.0     112.0
# 1116        28.0  2018.0           412.0            300.0     112.0
# 1117        29.0  2019.0           412.0            300.0     112.0
# 1118        30.0  2020.0           412.0            300.0     112.0
# 1119        31.0  2021.0           412.0            300.0     112.0
#
#       semi_detached    row  apartment  total_dwelling_market  \
# 0              57.0    6.0      387.0                 2274.0
# ...

# %%
data['Date'] = pd.to_datetime(data['Date'])
data['year'] = data['Date'].dt.year
print(data)
# Out:
#       Unnamed: 0    year  total_dwelling  single_detached  multiple  \
# 0            0.0  1961.0          3297.0           2847.0     450.0
# 1            1.0  1961.0          1950.0           1589.0     361.0
# 2            2.0  1961.0          2310.0           1683.0     627.0
# 3            3.0  1961.0          2425.0           1874.0     551.0
# 4            4.0  1961.0          3197.0           2441.0     756.0
# ...          ...     ...             ...              ...       ...
# 1115        27.0     NaN           412.0            300.0     112.0
# 1116        28.0     NaN           412.0            300.0     112.0
# 1117        29.0     NaN           412.0            300.0     112.0
# 1118        30.0     NaN           412.0            300.0     112.0
# 1119        31.0     NaN           412.0            300.0     112.0
#
#       semi_detached    row  apartment  total_dwelling_market  \
# 0              57.0    6.0      387.0                 2274.0
# ...

# %%
# Independent Variables
X = mrrate.drop(['Interest Rate'], axis = 1)
y = mrrate['Interest Rate']
X = np.array(X)
y = np.array(y)

# %%
from sklearn.model_selection import train_test_split
# Let us split our dataset into test and train groups with  8:2 ratio.
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size = 0.2,
                                                    random_state = 10)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14456/134291960.py in <module>
#       1 from sklearn.linear_model import LinearRegression
#       2 model = LinearRegression()
# ----> 3 model.fit(X_train, y_train)
#
# E:\Anaconda\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     682         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     683
# --> 684         X, y = self._validate_data(
#     685             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     686         )
#
# E:\Anaconda\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     594                 y = check_array(y, input_name="y", **check_y_params)
#     595             else:
# --> 596                 X, y = check_X_y(X, y, **check_params)
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import confusion_matrix
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from mlxtend.plotting import plot_sequential_feature_selection as plot_sfs
import matplotlib.pyplot as plt
from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
import seaborn as sns

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_model = KNeighborsClassifier(n_neighbors=3)
dt_model = DecisionTreeClassifier()
rf_model = RandomForestClassifier()
nb_model = GaussianNB()
lda_model = LinearDiscriminantAnalysis()
qda_model = LinearDiscriminantAnalysis()

# %%
knn_model.fit(X_train,y_train)
y_pred_knn = knn_model.predict(X)
y_true = y
cf_matrix = confusion_matrix(y_true, y_pred_knn)
print("Accuracy of the KNN model:",accuracy_score(y_true, y_pred_knn))
print("Precision Score of the KNN model:",precision_score(y_true, y_pred_knn))
print("Recall Score of the KNN model:",recall_score(y_true, y_pred_knn))
print("F1 Score of the KNN model:",f1_score(y_true, y_pred_knn))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14456/2221197771.py in <module>
# ----> 1 knn_model.fit(X_train,y_train)
#       2 y_pred_knn = knn_model.predict(X)
#       3 y_true = y
#       4 cf_matrix = confusion_matrix(y_true, y_pred_knn)
#       5 print("Accuracy of the KNN model:",accuracy_score(y_true, y_pred_knn))
#
# E:\Anaconda\lib\site-packages\sklearn\neighbors\_classification.py in fit(self, X, y)
#     205         self.weights = _check_weights(self.weights)
#     206
# --> 207         return self._fit(X, y)
#     208
#     209     def predict(self, X):
#
# E:\Anaconda\lib\site-packages\sklearn\neighbors\_base.py in _fit(self, X, y)
#     405         if self._get_tags()["requires_y"]:
#     406             if not isinstance(X, (KDTree, BallTree, NeighborsBase)):
# --> 407                 X, y = self._validate_data(
# ...
